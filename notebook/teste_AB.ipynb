# %% [markdown]
# ### Carregamento e Verificação dos Dados

# %%
import pandas as pd
from io import StringIO

# The clean dataset, stored as a multi-line string within the script
data = """
Data,Plataforma,Criativo,Impressões,Cliques,Conversões,CTR (%),CVR (%),Gasto (R$)
2025-08-25,Meta Ads,A,12000,350,18,2.92,5.14,250
2025-08-25,Meta Ads,B,12500,420,25,3.36,5.95,260
2025-08-25,Google Ads,A,8500,280,15,3.29,5.36,200
2025-08-25,Google Ads,B,9000,310,18,3.44,5.81,210
2025-08-25,TikTok Ads,A,7000,210,10,3.00,4.76,180
2025-08-25,TikTok Ads,B,7500,260,14,3.47,5.38,190
2025-08-26,Meta Ads,A,13500,400,22,2.96,5.50,280
2025-08-26,Meta Ads,B,14000,480,30,3.43,6.25,295
2025-08-26,Google Ads,A,9200,300,16,3.26,5.33,220
2025-08-26,Google Ads,B,9600,340,20,3.54,5.88,230
2025-08-26,TikTok Ads,A,7800,230,12,2.95,5.22,200
2025-08-26,TikTok Ads,B,8100,280,15,3.46,5.36,215
2025-08-27,Meta Ads,A,11500,320,19,2.78,5.94,240
2025-08-27,Meta Ads,B,12000,390,24,3.25,6.15,250
2025-08-27,Google Ads,A,8000,260,14,3.25,5.38,190
2025-08-27,Google Ads,B,8400,290,17,3.45,5.86,200
2025-08-27,TikTok Ads,A,6800,200,9,2.94,4.50,170
2025-08-27,TikTok Ads,B,7100,250,13,3.52,5.20,185
2025-08-28,Meta Ads,A,14200,450,24,3.17,5.33,300
2025-08-28,Meta Ads,B,14800,510,32,3.45,6.27,315
2025-08-28,Google Ads,A,9800,320,18,3.27,5.62,235
2025-02-28,Google Ads,B,10200,360,22,3.53,6.11,245
2025-08-28,TikTok Ads,A,8500,250,14,2.94,5.60,220
2025-08-28,TikTok Ads,B,9000,300,18,3.33,6.00,235
2025-08-29,Meta Ads,A,11000,310,17,2.82,5.48,220
2025-08-29,Meta Ads,B,11500,380,23,3.30,6.05,240
2025-08-29,Google Ads,A,7500,240,13,3.20,5.42,180
2025-08-29,Google Ads,B,7900,270,16,3.42,5.93,190
2025-08-29,TikTok Ads,A,6500,190,8,2.92,4.21,160
2025-08-29,TikTok Ads,B,6800,240,12,3.53,5.00,175
2025-08-30,Meta Ads,A,15000,480,26,3.20,5.42,320
2025-08-30,Meta Ads,B,15500,550,35,3.55,6.36,340
2025-08-30,Google Ads,A,10500,350,19,3.33,5.43,250
2025-08-30,Google Ads,B,10800,390,24,3.61,6.15,265
2025-08-30,TikTok Ads,A,9000,270,15,3.00,5.56,230
2025-08-30,TikTok Ads,B,9500,320,19,3.37,5.94,245
"""

# Read the string data into a DataFrame
df = pd.read_csv(StringIO(data))

# Display the first 5 rows and a summary of the data
print("DataFrame loaded directly from string. Here's a quick look:")
print(df.head())

print("\nAnd here's a summary of the data types and non-null values:")
print(df.info())
# Out:
# DataFrame loaded directly from string. Here's a quick look:
#          Data  Plataforma Criativo  Impressões  Cliques  Conversões  CTR (%)  \
# 0  2025-08-25    Meta Ads        A       12000      350          18     2.92
# 1  2025-08-25    Meta Ads        B       12500      420          25     3.36
# 2  2025-08-25  Google Ads        A        8500      280          15     3.29
# 3  2025-08-25  Google Ads        B        9000      310          18     3.44
# 4  2025-08-25  TikTok Ads        A        7000      210          10     3.00
#
#    CVR (%)  Gasto (R$)
# 0     5.14         250
# 1     5.95         260
# 2     5.36         200
# 3     5.81         210
# 4     4.76         180
#
# And here's a summary of the data types and non-null values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Data        36 non-null     object
# ...

# %% [markdown]
# ### Análise Exploratória

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO

# O dataset limpo, como um string de texto
data = """
Data,Plataforma,Criativo,Impressões,Cliques,Conversões,CTR (%),CVR (%),Gasto (R$)
2025-08-25,Meta Ads,A,12000,350,18,2.92,5.14,250
2025-08-25,Meta Ads,B,12500,420,25,3.36,5.95,260
2025-08-25,Google Ads,A,8500,280,15,3.29,5.36,200
2025-08-25,Google Ads,B,9000,310,18,3.44,5.81,210
2025-08-25,TikTok Ads,A,7000,210,10,3.00,4.76,180
2025-08-25,TikTok Ads,B,7500,260,14,3.47,5.38,190
2025-08-26,Meta Ads,A,13500,400,22,2.96,5.50,280
2025-08-26,Meta Ads,B,14000,480,30,3.43,6.25,295
2025-08-26,Google Ads,A,9200,300,16,3.26,5.33,220
2025-08-26,Google Ads,B,9600,340,20,3.54,5.88,230
2025-08-26,TikTok Ads,A,7800,230,12,2.95,5.22,200
2025-08-26,TikTok Ads,B,8100,280,15,3.46,5.36,215
2025-08-27,Meta Ads,A,11500,320,19,2.78,5.94,240
2025-08-27,Meta Ads,B,12000,390,24,3.25,6.15,250
2025-08-27,Google Ads,A,8000,260,14,3.25,5.38,190
2025-08-27,Google Ads,B,8400,290,17,3.45,5.86,200
2025-08-27,TikTok Ads,A,6800,200,9,2.94,4.50,170
2025-08-27,TikTok Ads,B,7100,250,13,3.52,5.20,185
2025-08-28,Meta Ads,A,14200,450,24,3.17,5.33,300
2025-08-28,Meta Ads,B,14800,510,32,3.45,6.27,315
2025-08-28,Google Ads,A,9800,320,18,3.27,5.62,235
2025-02-28,Google Ads,B,10200,360,22,3.53,6.11,245
2025-08-28,TikTok Ads,A,8500,250,14,2.94,5.60,220
2025-08-28,TikTok Ads,B,9000,300,18,3.33,6.00,235
2025-08-29,Meta Ads,A,11000,310,17,2.82,5.48,220
2025-08-29,Meta Ads,B,11500,380,23,3.30,6.05,240
2025-08-29,Google Ads,A,7500,240,13,3.20,5.42,180
2025-08-29,Google Ads,B,7900,270,16,3.42,5.93,190
2025-08-29,TikTok Ads,A,6500,190,8,2.92,4.21,160
2025-08-29,TikTok Ads,B,6800,240,12,3.53,5.00,175
2025-08-30,Meta Ads,A,15000,480,26,3.20,5.42,320
2025-08-30,Meta Ads,B,15500,550,35,3.55,6.36,340
2025-08-30,Google Ads,A,10500,350,19,3.33,5.43,250
2025-08-30,Google Ads,B,10800,390,24,3.61,6.15,265
2025-08-30,TikTok Ads,A,9000,270,15,3.00,5.56,230
2025-08-30,TikTok Ads,B,9500,320,19,3.37,5.94,245
"""

# Ler a string como um DataFrame
df = pd.read_csv(StringIO(data))

# A seção a seguir é o que você executaria para obter o output
# numérico e gráfico.

# 1. Análise Numérica
# Agrupar dados por Criativo e Plataforma e somar as métricas
df_grouped = df.groupby(['Plataforma', 'Criativo']).agg({
    'Impressões': 'sum',
    'Cliques': 'sum',
    'Conversões': 'sum',
    'Gasto (R$)': 'sum'
}).reset_index()

# Calcular CTR e CVR médios a partir dos dados agregados
df_grouped['CTR_medio'] = (df_grouped['Cliques'] / df_grouped['Impressões']) * 100
df_grouped['CVR_medio'] = (df_grouped['Conversões'] / df_grouped['Cliques']) * 100

print("Desempenho agregado por Plataforma e Criativo:")
print(df_grouped)

# 2. Análise Gráfica
sns.set_theme(style="whitegrid")

# Criar a figura para os subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Gráfico 1: CVR Médio por Criativo
df_cvr = df.groupby('Criativo')['CVR (%)'].mean().reset_index()
sns.barplot(x='Criativo', y='CVR (%)', data=df_cvr, ax=axes[0])
axes[0].set_title('CVR Médio Geral por Criativo', fontweight='bold')
axes[0].set_ylabel('CVR (%)')
axes[0].set_xlabel('Criativo')

# Gráfico 2: CVR Médio por Criativo e Plataforma
sns.barplot(x='Plataforma', y='CVR (%)', hue='Criativo', data=df, ax=axes[1])
axes[1].set_title('CVR Médio por Criativo e Plataforma', fontweight='bold')
axes[1].set_ylabel('CVR (%)')
axes[1].set_xlabel('Plataforma')
axes[1].legend(title='Criativo')

# Gráfico 3: Gasto Total por Criativo
sns.barplot(x='Criativo', y='Gasto (R$)', data=df, ax=axes[2], estimator=sum)
axes[2].set_title('Gasto Total por Criativo', fontweight='bold')
axes[2].set_ylabel('Gasto (R$)')
axes[2].set_xlabel('Criativo')

plt.tight_layout()
plt.show()
# Out:
# Desempenho agregado por Plataforma e Criativo:
#    Plataforma Criativo  Impressões  Cliques  Conversões  Gasto (R$)  \
# 0  Google Ads        A       53500     1750          95        1275
# 1  Google Ads        B       55900     1960         117        1340
# 2    Meta Ads        A       77200     2310         126        1610
# 3    Meta Ads        B       80300     2730         169        1700
# 4  TikTok Ads        A       45600     1350          68        1160
# 5  TikTok Ads        B       48000     1650          91        1245
#
#    CTR_medio  CVR_medio
# 0   3.271028   5.428571
# 1   3.506261   5.969388
# 2   2.992228   5.454545
# 3   3.399751   6.190476
# 4   2.960526   5.037037
# 5   3.437500   5.515152

# %% [markdown]
# #### O Criativo B apresentou uma melhor performance em comparação ao criativo A embora tenha recebido um orçamento um pouco maior que o A. Agora vamos avaliar estatisticamente a performance de ambor.

# %% [markdown]
# ## Teste Estatístico e Visualuzação Gráfica

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from io import StringIO

# O dataset limpo, como um string de texto
data = """
Data,Plataforma,Criativo,Impressões,Cliques,Conversões,CTR (%),CVR (%),Gasto (R$)
2025-08-25,Meta Ads,A,12000,350,18,2.92,5.14,250
2025-08-25,Meta Ads,B,12500,420,25,3.36,5.95,260
2025-08-25,Google Ads,A,8500,280,15,3.29,5.36,200
2025-08-25,Google Ads,B,9000,310,18,3.44,5.81,210
2025-08-25,TikTok Ads,A,7000,210,10,3.00,4.76,180
2025-08-25,TikTok Ads,B,7500,260,14,3.47,5.38,190
2025-08-26,Meta Ads,A,13500,400,22,2.96,5.50,280
2025-08-26,Meta Ads,B,14000,480,30,3.43,6.25,295
2025-08-26,Google Ads,A,9200,300,16,3.26,5.33,220
2025-08-26,Google Ads,B,9600,340,20,3.54,5.88,230
2025-08-26,TikTok Ads,A,7800,230,12,2.95,5.22,200
2025-08-26,TikTok Ads,B,8100,280,15,3.46,5.36,215
2025-08-27,Meta Ads,A,11500,320,19,2.78,5.94,240
2025-08-27,Meta Ads,B,12000,390,24,3.25,6.15,250
2025-08-27,Google Ads,A,8000,260,14,3.25,5.38,190
2025-08-27,Google Ads,B,8400,290,17,3.45,5.86,200
2025-08-27,TikTok Ads,A,6800,200,9,2.94,4.50,170
2025-08-27,TikTok Ads,B,7100,250,13,3.52,5.20,185
2025-08-28,Meta Ads,A,14200,450,24,3.17,5.33,300
2025-08-28,Meta Ads,B,14800,510,32,3.45,6.27,315
2025-08-28,Google Ads,A,9800,320,18,3.27,5.62,235
2025-02-28,Google Ads,B,10200,360,22,3.53,6.11,245
2025-08-28,TikTok Ads,A,8500,250,14,2.94,5.60,220
2025-08-28,TikTok Ads,B,9000,300,18,3.33,6.00,235
2025-08-29,Meta Ads,A,11000,310,17,2.82,5.48,220
2025-08-29,Meta Ads,B,11500,380,23,3.30,6.05,240
2025-08-29,Google Ads,A,7500,240,13,3.20,5.42,180
2025-08-29,Google Ads,B,7900,270,16,3.42,5.93,190
2025-08-29,TikTok Ads,A,6500,190,8,2.92,4.21,160
2025-08-29,TikTok Ads,B,6800,240,12,3.53,5.00,175
2025-08-30,Meta Ads,A,15000,480,26,3.20,5.42,320
2025-08-30,Meta Ads,B,15500,550,35,3.55,6.36,340
2025-08-30,Google Ads,A,10500,350,19,3.33,5.43,250
2025-08-30,Google Ads,B,10800,390,24,3.61,6.15,265
2025-08-30,TikTok Ads,A,9000,270,15,3.00,5.56,230
2025-08-30,TikTok Ads,B,9500,320,19,3.37,5.94,245
"""

# Ler o string de dados
df = pd.read_csv(StringIO(data))

# Preparar os dados para o teste T
cvr_criativo_a = df[df['Criativo'] == 'A']['CVR (%)']
cvr_criativo_b = df[df['Criativo'] == 'B']['CVR (%)']

# 1. Teste Estatístico (Teste T)
t_stat, p_value = stats.ttest_ind(cvr_criativo_a, cvr_criativo_b, equal_var=False)
print(f"Estatística T: {t_stat:.4f}")
print(f"P-valor: {p_value:.4f}")

# 2. Visualização Gráfica (Boxplot)
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.boxplot(x='Criativo', y='CVR (%)', data=df)
plt.title('Distribuição da Taxa de Conversão (CVR) por Criativo', fontsize=14, fontweight='bold')
plt.xlabel('Criativo', fontsize=12)
plt.ylabel('CVR (%)', fontsize=12)
plt.show()
# Out:
# Estatística T: -4.3375
# P-valor: 0.0001
